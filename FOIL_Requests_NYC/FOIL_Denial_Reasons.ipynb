# %%
import pandas as pd

# %%
df = pd.read_csv("https://data.cityofnewyork.us/api/views/93kn-fhqt/rows.csv?accessType=DOWNLOAD")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %%
denials = df[df['Is the data set on Open Data?'] == "Not on Open Data Plan"]
number_of_requests_denied = denials.sort_values(by='Number of FOIL requests', ascending=False)

# %%
number_of_requests_denied
# Out:
#                                                              Agency  \
# 96                     Department of Environmental Protection (DEP)
# 100                    Department of Environmental Protection (DEP)
# 185                              Department of Transportation (DOT)
# 57              Department of Consumer and Worker Protection (DCWP)
# 15                                    Department of Buildings (DOB)
# 184                              Department of Transportation (DOT)
# 157                        Department of Parks and Recreation (DPR)
# 99                     Department of Environmental Protection (DEP)
# 213                      Mayor's Office of Contract Services (MOCS)
# 103                                     Department of Finance (DOF)
# 107                                     Department of Finance (DOF)
# 154                        Department of Parks and Recreation (DPR)
# 192                              Department of Transportation (DOT)
# ...

# %%
percent_denied = number_of_requests_denied.shape[0] / df.shape[0] * 100
